# %%
from fastai.vision.all import *
from fastai.vision.widgets import *
import urllib.request

# %%
# !pip install viola
# !python -m ipykernel install --user --name=fastai
# Out:
# Requirement already satisfied: viola in c:\users\stefan\anaconda3\lib\site-packages (0.3.8)
# Installed kernelspec fastai in C:\Users\Stefan\AppData\Roaming\jupyter\kernels\fastai

# %%
import pathlib
temp = pathlib.PosixPath
pathlib.PosixPath = pathlib.WindowsPath

# %%
path = Path()
learn_inf = load_learner(path/'export.pkl',cpu=True)

# %%
btn_upload = widgets.FileUpload()

# %%
btn_run = widgets.Button(description='Classify')

# %%
out_pl = widgets.Output()
lbl_pred = widgets.Label()

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(224,224))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
VBox([widgets.Label('Select your piece!'), 
      btn_upload, btn_run, out_pl, lbl_pred])
# Out:
# VBox(children=(Label(value='Select your piece!'), FileUpload(value={}, description='Upload'), Button(descripti…
